# %%
# import the libray
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('dataset.csv')

# %%
data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# # Explore the data

# %%
# print the shape
data.shape
# Out:
# (1470, 35)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
# print only columns
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
# print only dtypes
data.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# # Selection of data

# %%
data['Age'] # Series
# Out:
# 0       41
# 1       49
# 2       37
# 3       33
# 4       27
#         ..
# 1465    36
# 1466    39
# 1467    27
# 1468    49
# 1469    34
# Name: Age, Length: 1470, dtype: int64

# %%
# print first 5 columns of data
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# loc method(name of col) & iloc(index of col)
data.loc[:,'Age':'Department']
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
# [1470 rows x 5 columns]

# %%
# print only fisrt 20 rows of these 5 columns
data.loc[0:19,'Age':'Department'] # loc takes exact index
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department
# 0    41       Yes      Travel_Rarely       1102                   Sales
# 1    49        No  Travel_Frequently        279  Research & Development
# 2    37       Yes      Travel_Rarely       1373  Research & Development
# 3    33        No  Travel_Frequently       1392  Research & Development
# 4    27        No      Travel_Rarely        591  Research & Development
# 5    32        No  Travel_Frequently       1005  Research & Development
# 6    59        No      Travel_Rarely       1324  Research & Development
# 7    30        No      Travel_Rarely       1358  Research & Development
# 8    38        No  Travel_Frequently        216  Research & Development
# 9    36        No      Travel_Rarely       1299  Research & Development
# 10   35        No      Travel_Rarely        809  Research & Development
# 11   29        No      Travel_Rarely        153  Research & Development
# ...

# %%
# select only age, att, dept, education
data.loc[:,('Age','Attrition','Department','TotalWorkingYears')]
# Out:
#       Age Attrition              Department  TotalWorkingYears
# 0      41       Yes                   Sales                  8
# 1      49        No  Research & Development                 10
# 2      37       Yes  Research & Development                  7
# 3      33        No  Research & Development                  8
# 4      27        No  Research & Development                  6
# ...   ...       ...                     ...                ...
# 1465   36        No  Research & Development                 17
# 1466   39        No  Research & Development                  9
# 1467   27        No  Research & Development                  6
# 1468   49        No                   Sales                 17
# 1469   34        No  Research & Development                  6
#
# [1470 rows x 4 columns]

# %%
# iloc
data.iloc[:,2:5]
# Out:
#          BusinessTravel  DailyRate              Department
# 0         Travel_Rarely       1102                   Sales
# 1     Travel_Frequently        279  Research & Development
# 2         Travel_Rarely       1373  Research & Development
# 3     Travel_Frequently       1392  Research & Development
# 4         Travel_Rarely        591  Research & Development
# ...                 ...        ...                     ...
# 1465  Travel_Frequently        884  Research & Development
# 1466      Travel_Rarely        613  Research & Development
# 1467      Travel_Rarely        155  Research & Development
# 1468  Travel_Frequently       1023                   Sales
# 1469      Travel_Rarely        628  Research & Development
#
# [1470 rows x 3 columns]

# %%
# extract data of first 15 rows of att,dept,education
data.iloc[:15,[1,4,6]]
# Out:
#    Attrition              Department  Education
# 0        Yes                   Sales          2
# 1         No  Research & Development          1
# 2        Yes  Research & Development          2
# 3         No  Research & Development          4
# 4         No  Research & Development          1
# 5         No  Research & Development          2
# 6         No  Research & Development          3
# 7         No  Research & Development          1
# 8         No  Research & Development          3
# 9         No  Research & Development          3
# 10        No  Research & Development          3
# 11        No  Research & Development          2
# 12        No  Research & Development          1
# 13        No  Research & Development          2
# 14       Yes  Research & Development          3

# %%
# only last column
data.iloc[:,-1]
# Out:
# 0       5
# 1       7
# 2       0
# 3       0
# 4       2
#        ..
# 1465    3
# 1466    7
# 1467    3
# 1468    8
# 1469    2
# Name: YearsWithCurrManager, Length: 1470, dtype: int64

# %% [markdown]
# # Conditional Selection

# %%
# see employees those are more than 40
data['Age']>40
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 1465    False
# 1466    False
# 1467    False
# 1468     True
# 1469    False
# Name: Age, Length: 1470, dtype: bool

# %%
# show whole data where age >40
data[data['Age']>40]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 6      59        No      Travel_Rarely       1324  Research & Development
# 18     53        No      Travel_Rarely       1219                   Sales
# 25     53        No      Travel_Rarely       1282  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1448   41        No      Travel_Rarely        930                   Sales
# 1452   50       Yes  Travel_Frequently        878                   Sales
# 1454   45        No      Travel_Rarely        374                   Sales
# 1461   50       Yes      Travel_Rarely        410                   Sales
# 1468   49        No  Travel_Frequently       1023                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
data[data['Age']>40].shape[0]
# Out:
# 465

# %%
data.shape[0]
# Out:
# 1470

# %%
data.shape[1]
# Out:
# 35

# %%
a=b assignment

a==b comparision
# Out:
#   File "<ipython-input-21-8e3aa3c30492>", line 1
#     a=b assignment
#                  ^
# SyntaxError: invalid syntax

# %%
# Age must >40 and depart is Sales
data[(data['Age']>40) & (data['Department']=='Sales')].shape[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10440\3420594646.py in <module>
#       1 # Age must >40 and depart is Sales
# ----> 2 data[(data['Age']>40) & (data['Department']=='Sales')].shape[0]
#
# NameError: name 'data' is not defined

# %% [markdown]
# # Check Null Values

# %%
data.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10440\1252651195.py in <module>
# ----> 1 data.isnull().sum()
#
# NameError: name 'data' is not defined

# %%
data.isnull().sum().any()

# %%
# Null value treatment
# Percentage 

(data.isnull().sum()/len(data))*100

# %%
# How to treat null values-
# 50% values are null- drop them
data.dropna(inplace=True) # change permanent
# numeric data- mean, median
# catgorical value- Most frequent values- mode, NA
df['dept'].fillna('Sales',inplace=True)

# %% [markdown]
# # Groupby

# %%
data.groupby('Department')

# %%
data.groupby('Department').count()

# %%
data.groupby('Department')['Age'].count()

# %%
data.groupby('Department').sum()

# %%
data.groupby('Department').max()

# %%
data.groupby('Department').min()

# %%
data.columns

# %%
data.groupby('Department')['MonthlyIncome'].agg(['mean','sum','max','min','count'])

# %%
data.groupby('EducationField')['MonthlyIncome'].agg(['mean','sum','max','min','count'])

# %%
data.groupby(['Department','Attrition']).count()

# %%
data.groupby(['Department','Attrition'])['MonthlyIncome'].count()

# %%
# print the count of values for each columns
for i in data.columns:
    print(i,":",data[i].value_counts())
    print("_"*40)
    print("_"*40)
# Out:
# Age : 35    78
# 34    77
# 31    69
# 36    69
# 29    68
# 32    61
# 30    60
# 33    58
# 38    58
# 40    57
# 37    50
# 27    48
# 28    48
# 42    46
# 39    42
# 45    41
# 41    40
# 26    39
# 46    33
# 44    33
# 43    32
# 50    30
# 24    26
# 25    26
# 47    24
# 49    24
# 55    22
# 48    19
# 51    19
# 53    19
# 52    18
# 54    18
# 22    16
# 56    14
# 58    14
# 23    14
# 21    13
# 20    11
# 59    10
# 19     9
# 18     8
# 60     5
# 57     4
# Name: Age, dtype: int64
# ________________________________________
# ________________________________________
# Attrition : No     1233
# Yes     237
# Name: Attrition, dtype: int64
# ________________________________________
# ________________________________________
# BusinessTravel : Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
# ________________________________________
# ________________________________________
# DailyRate : 691     6
# ...

# %%
# print unique values of each columns
for i in data.columns:
    print(i,":",data[i].unique())
    print("_"*40)
    print("_"*40)

# %%
# Observation- Attrition- imbalance dataset
# Drop Unnecessary columns

# %%
# Drop the columns
data.columns

# %%
# imbalanced-
# hospital -cancer prediction- 100 - 60-not, 40 cancer
# machine learning- have cancer- dont have cancer

# %%
df=data

# %%
df=data.copy()

# %%
data.shape
# Out:
# (1470, 35)

# %%
df.drop(['Over18','StandardHours','EmployeeNumber','EmployeeCount'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (1470, 31)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
df[['RelationshipSatisfaction','JobSatisfaction','EnvironmentSatisfaction','JobInvolvement']]
# Out:
#       RelationshipSatisfaction  JobSatisfaction  EnvironmentSatisfaction  \
# 0                            1                4                        2
# 1                            4                2                        3
# 2                            2                3                        4
# 3                            3                3                        4
# 4                            4                2                        1
# ...                        ...              ...                      ...
# 1465                         3                4                        3
# 1466                         1                1                        4
# 1467                         2                2                        2
# 1468                         4                2                        4
# 1469                         1                3                        2
#
#       JobInvolvement
# 0                  3
# 1                  2
# 2                  2
# ...

# %%
#df[['RelationshipSatisfaction','JobSatisfaction','EnvironmentSatisfaction','JobInvolvement']] 'WorkLifeBalance'
df['TotalSatisfaction_mean']=(df['RelationshipSatisfaction']+df['JobSatisfaction']+df['EnvironmentSatisfaction']+df['JobInvolvement']+
                             +df['WorkLifeBalance'])/5

# %%
df['TotalSatisfaction_mean']
# Out:
# 0       2.2
# 1       2.8
# 2       2.8
# 3       3.2
# 4       2.6
#        ...
# 1465    3.4
# 1466    2.2
# 1467    2.6
# 1468    2.8
# 1469    2.8
# Name: TotalSatisfaction_mean, Length: 1470, dtype: float64

# %%
df.shape
# Out:
# (1470, 32)

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# ...

# %%
# Create a new columns based on some condition
def satif(df):
    if df['TotalSatisfaction_mean']>2.35:
        return True
    else:
        return False

# %%
df['Overall_satisf']=df.apply(lambda df:satif(df),axis=1)
df['Overall_satisf']
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1465     True
# 1466    False
# 1467     True
# 1468     True
# 1469     True
# Name: Overall_satisf, Length: 1470, dtype: bool

# %%
df.shape
# Out:
# (1470, 33)

# %%
df['Overall_satisf'].value_counts()
# Out:
# 1    1244
# 0     226
# Name: Overall_satisf, dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'TotalSatisfaction_mean', 'Overall_satisf'],
#       dtype='object')

# %%
df['NumCompaniesWorked']
# Out:
# 0       8
# 1       1
# 2       6
# 3       1
# 4       9
#        ..
# 1465    4
# 1466    4
# 1467    1
# 1468    2
# 1469    2
# Name: NumCompaniesWorked, Length: 1470, dtype: int64

# %%
# create a new column moving people based on cond if he has worked for more than 4 companies

# %%
def moving(data):
    if data['NumCompaniesWorked']>4:
        return 1
    else:
        return 0

df['Moving']=df.apply(lambda df:moving(df),axis=1)
df['Moving']
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Moving, Length: 1470, dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'TotalSatisfaction_mean', 'Overall_satisf', 'Moving'],
#       dtype='object')

# %%
# drop the unnecessary columns
#Generate a separate dataset for numerical and categorical variables

# %%
df_object=df.select_dtypes(include='object')

# %%
df_object.shape
# Out:
# (1470, 8)

# %%
df_object
# Out:
#      Attrition     BusinessTravel              Department EducationField  \
# 0          Yes      Travel_Rarely                   Sales  Life Sciences
# 1           No  Travel_Frequently  Research & Development  Life Sciences
# 2          Yes      Travel_Rarely  Research & Development          Other
# 3           No  Travel_Frequently  Research & Development  Life Sciences
# 4           No      Travel_Rarely  Research & Development        Medical
# ...        ...                ...                     ...            ...
# 1465        No  Travel_Frequently  Research & Development        Medical
# 1466        No      Travel_Rarely  Research & Development        Medical
# 1467        No      Travel_Rarely  Research & Development  Life Sciences
# 1468        No  Travel_Frequently                   Sales        Medical
# 1469        No      Travel_Rarely  Research & Development        Medical
#
#       Gender                    JobRole MaritalStatus OverTime
# ...

# %%
# give list 
list_object=df_object.columns.tolist()

# %%
list_object
# Out:
# ['Attrition',
#  'BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'OverTime']

# %%
df_num=df.select_dtypes(exclude='object')

# %%
df_num.shape
# Out:
# (1470, 26)
